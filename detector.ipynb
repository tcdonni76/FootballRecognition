# %% [markdown]
# <a href="https://colab.research.google.com/github/tcdonni76/FootballRecognition/blob/main/detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.134 opencv-python==4.8.0.74 roboflow --quiet
# %pip install -qr requirements.txt comet_ml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.1/629.1 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# ...

# %%
import os

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt comet_ml
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16308, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 16308 (delta 96), reused 96 (delta 33), pack-reused 16103
# Receiving objects: 100% (16308/16308), 15.09 MiB | 11.72 MiB/s, done.
# Resolving deltas: 100% (11127/11127), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.9/589.9 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 93.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.8/699.8 kB 57.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 94.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 30.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 16.9 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="i8sra0QYM63X3DQYBElR")
project = rf.workspace("smart-football-object-detection").project("smart-football-object-detection")
dataset = project.version(11).download("yolov5")

os.listdir()
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Smart-Football:-Object-Detection-11 in yolov5pytorch:: 100%|██████████| 25634/25634 [00:05<00:00, 4898.11it/s]
# ['requirements.txt',
#  'export.py',
#  'tutorial.ipynb',
#  '.gitattributes',
#  '.github',
#  'Smart-Football:-Object-Detection-11',
#  'README.md',
#  'train.py',
#  'benchmarks.py',
#  'classify',
#  'CONTRIBUTING.md',
#  'pyproject.toml',
#  'LICENSE',
#  'val.py',
#  '.git',
#  'README.zh-CN.md',
#  '.dockerignore',
#  '.gitignore',
#  'models',
#  'utils',
#  'hubconf.py',
#  'segment',
#  'data',
#  'detect.py',
#  'CITATION.cff']

# %%
# !python train.py --img 640 --batch 16 --epochs 10 --data Smart-Football:-Object-Detection-11/data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-01-13 16:13:27.579546: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-13 16:13:27.579601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-13 16:13:27.581536: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp -r runs/train/exp ../gdrive/MyDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')



"""# Copy the trained model to Google Drive
# !cp -r runs/train/exp/weights/best.pt /content/gdrive/My\ Drive"""
# Out:
# Mounted at /content/gdrive
# '# Copy the trained model to Google Drive\n!cp -r runs/train/exp/weights/best.pt /content/gdrive/My\\ Drive'

# %%
os.listdir('../gdrive/MyDrive')
# Out:
# ['Google Photos',
#  'Assured Shorthold Tenancy Agreement (UK) (1).pdf',
#  'Assured Shorthold Tenancy Agreement (UK) (1).gdoc',
#  'Assured Shorthold Tenancy Agreement (UK).pdf',
#  'Assured Shorthold Tenancy Agreement (UK).gdoc',
#  'Photos etc',
#  'Football Clips',
#  'dataTesting.csv',
#  'Writing pieces',
#  'Guarantor document and payslip.pdf',
#  'Guarantor document and payslip.gdoc',
#  'Neoliberalism essay (1).docx',
#  'Neoliberalism essay.docx',
#  'Software development management structures and system architecture structures (1).docx',
#  'Software development management structures and system architecture structures.docx',
#  'Colab Notebooks',
#  'Critical Paper Review - TCD (1).docx',
#  'Team 18 demo video - Made with Clipchamp_1685397827677.mp4',
#  'fbref_to_tm_mapping.csv',
#  'Untitled document.gdoc',
#  'benbrns.nds',
#  'Man City go THIRD- Manchester City 2-0 Sheffield United Premier League Highlights.mp4',
#  'your_image.png',
# ...

# %%
os.listdir('runs/detect/exp')
# Out:
# ['grealish.png']

# %%
# !python detect.py --weights ../gdrive/MyDrive/best.pt --img 416 --conf 0.2 --source ../gdrive/MyDrive/your_image.png
# Out:
# detect: weights=['../gdrive/MyDrive/best.pt'], source=../gdrive/MyDrive/your_image.png, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-272-gde64179 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Class Names: {0: 'ball', 1: 'goalkeeper', 2: 'referee', 3: 'soccer-player'}
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/gdrive/MyDrive/your_image.png: 224x416 1 referee, 15 soccer-players, 50.9ms
# Speed: 0.4ms pre-process, 50.9ms inference, 608.0ms NMS per image at shape (1, 3, 416, 416)
# ...

# %%
from ultralytics import YOLO
import torch

model = YOLO("yolov5su.pt")

model.load_state_dict(torch.load('../gdrive/MyDrive/exp/weights/best.pt'), strict=False)

# !python detect.py --source ../gdrive/MyDrive/grealish.png --weights ../gdrive/MyDrive/exp/weights/best.pt --img-size 640
# Out:
# detect: weights=['../gdrive/MyDrive/exp/weights/best.pt'], source=../gdrive/MyDrive/grealish.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-274-g7d9a117 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/gdrive/MyDrive/grealish.png: 384x640 1 ball, 1 soccer-player, 58.1ms
# Speed: 0.6ms pre-process, 58.1ms inference, 623.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from PIL import Image
from IPython.display import display

img = Image.open('../gdrive/MyDrive/grealish.png')

display(img)

print(os.listdir())

img = Image.open('runs/detect/exp/grealish.png')

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1277x718>
# ['requirements.txt', 'export.py', 'tutorial.ipynb', '.gitattributes', '__pycache__', '.github', 'Smart-Football:-Object-Detection-11', 'README.md', 'train.py', 'benchmarks.py', 'classify', 'CONTRIBUTING.md', 'runs', 'pyproject.toml', 'LICENSE', 'yolov5su.pt', 'val.py', '.git', 'README.zh-CN.md', '.dockerignore', '.gitignore', 'models', 'utils', 'hubconf.py', 'segment', 'data', 'detect.py', 'CITATION.cff']
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1277x718>

# %%
# %pip install supervision

import supervision as sv
import numpy as np
from ultralytics import YOLO
import torch

VIDEO_PATH = "../gdrive/MyDrive/Man City go THIRD- Manchester City 2-0 Sheffield United Premier League Highlights.mp4"

model = YOLO("yolov5s.pt")
model.load_state_dict(torch.load('../gdrive/MyDrive/exp/weights/best.pt'), strict=False)

video_info = sv.VideoInfo.from_video_path(VIDEO_PATH)

def process_frame(frame: np.ndarray, _) -> np.ndarray:

    results = model(frame, imgsz=640)[0]

    detections = sv.Detections.from_ultralytics(results)

    box_annotator = sv.BoxAnnotator(thickness=2, text_thickness=2, text_scale=0.9)

    labels = [f"{model.names[class_id]} {confidence:0.2f}" for _, _, confidence, class_id, _ in detections]
    frame = box_annotator.annotate(scene=frame, detections=detections, labels=labels)

    return frame

sv.process_video(source_path=VIDEO_PATH, target_path=f"../gdrive/MyDrive/result_matchh.mp4", callback=process_frame)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 13 persons, 3 kites, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 5 kites, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 kites, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 kites, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 kites, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 kites, 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 kite, 11.2ms
# ...

# %%
# !cp result.mp4 ../gdrive/MyDrive

# %%
# !python detect.py --source ../gdrive/MyDrive/Man\ City\ go\ THIRD-\ Manchester\ City\ 2-0\ Sheffield\ United\ Premier\ League\ Highlights.mp4 --weights ../gdrive/MyDrive/exp/weights/best.pt --save-dir ../gdrive/MyDrive --img-size 640 --save-txt
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE] [--data DATA]
#                  [--imgsz IMGSZ [IMGSZ ...]] [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img] [--save-txt] [--save-csv]
#                  [--save-conf] [--save-crop] [--nosave] [--classes CLASSES [CLASSES ...]]
#                  [--agnostic-nms] [--augment] [--visualize] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS] [--hide-labels]
#                  [--hide-conf] [--half] [--dnn] [--vid-stride VID_STRIDE]
# detect.py: error: unrecognized arguments: --save-dir ../gdrive/MyDrive

# %%
from IPython.display import Video
from IPython.display import HTML

"""
v_path = 'runs/detect/exp3/Man City go THIRD- Manchester City 2-0 Sheffield United Premier League Highlights.mp4'
HTML(f'<video controls src="{v_path}"></video>')
"""
from IPython.display import HTML
from base64 import b64encode
mp4 = open('runs/detect/exp3/Man City go THIRD- Manchester City 2-0 Sheffield United Premier League Highlights.mp4','rb').read()
data_url = "data:runs/detect/exp3/Man City go THIRD- Manchester City 2-0 Sheffield United Premier League Highlights.mp4;base64," + b64encode(mp4).decode()

HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
# !cp runs/detect/exp3/Man\ City\ go\ THIRD-\ Manchester\ City\ 2-0\ Sheffield\ United\ Premier\ League\ Highlights.mp4 ../gdrive/MyDrive
